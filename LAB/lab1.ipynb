# %%
#LATIHAN KELAS <<LAB>> 
#12/1/2024

#INPUT OUTPUT

var = 5 
print(f"Number: {var}")
print("Number: ", var)
print(type(var))

number = input ("Input number: ")
print("Number 2: ", number)

#Aritmatika 
hasil = 6 **2
print(hasil)

#CONDITION
nilai = 85 
if(nilai > 80): 
    print("A")
elif(nilai > 70):
    print("B")
else: 
        print("Error")
        
#LOOPING 
for i in range(1,5):
    print(i)
    
i = 5
while (i<10): 
    print(i)
    i+=1
    
#String Function 
word = "Makan"
count_total = word.count("a")
print(count_total)

#List []

daftar_makan = ["Apel", "Mangga", "Jeruk"]

print(daftar_makan)

#set []
daftar_makanan2 = {"Apel", "Apel", "Mangga"}
print(daftar_makanan2)

#dict{}
daftar_makanan3 = {1: "apel", "2": "Jeruk"}
print(daftar_makanan3)
print(daftar_makanan3[1])


import numpy as np
arr = np.array([1, 2, 3])
print("Arr: ", arr)

zeros_arr = np.zeros((3, 3))
print("Zeros_arr: ", zeros_arr)

ones_arr = np.ones((3, 3))
print("One_arr: ", ones_arr)

range_arr = np.arange(0, 10, 2)
print("Range_arr: ", range_arr)

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
result_add = np.add(a, b)
print("result_add:", result_add)

dot_product = np.dot(a, b)
print("Dot: ", dot_product)

total = np.sum(a)
print("Total:", total)

average = np.mean(a)
print("Average:", average)

max_val = np.max(a)
print(max_val)

mean_val = np.mean([1,1,12,32,44,5,2,6])
print(mean_val)

median_val = np.median([1,1,12,32,44,5,2,6])
print(median_val)

std_dev = np.std([1,1,12,32,44,5,2,6])
print(std_dev)

random_arr = np.random.rand(3, 3)
print(random_arr)

normal_arr = np.random.randn(3, 3)
print(normal_arr)
